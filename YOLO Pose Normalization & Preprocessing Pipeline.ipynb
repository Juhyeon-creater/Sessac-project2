# %% [markdown]
# <a href="https://colab.research.google.com/github/Juhyeon-creater/Sessac-project2/blob/main/YOLO%20Pose%20Normalization%20%26%20Preprocessing%20Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.229)
# Requirement already satisfied: numpy<=2.3.4,>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib<=3.10.7,>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python<=4.12.0.88,>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow<=12.0.0,>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml<=6.0.3,>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests<=2.32.5,>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy<=1.16.3,>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch<=2.9.1,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision<=0.24.1,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil<=7.1.3,>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars<=1.35.2,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Requirement already satisfied: ultralytics-thop<=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10.7,>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10.7,>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10.7,>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10.7,>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10.7,>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10.7,>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10.7,>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<=2.32.5,>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<=2.32.5,>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<=2.32.5,>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<=2.32.5,>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<=2.9.1,>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10.7,>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<=2.9.1,>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<=2.9.1,>=1.8.0->ultralytics) (3.0.3)

# %%
import os


# [경로 설정]
drive_root = '/content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred'#{Hundred(자세파일)} - output 도 이 파일에 생성
# 1. 원본 영상이 있는 폴더 (경로를 확인해주세요!)
video_folder_path = os.path.join(drive_root, 'hundred_video') #동영상들어있는파일 경로
# 2. 정규화된 CSV를 저장할 폴더
norm_folder_path = os.path.join(drive_root, 'norm')  # 저장할 폴더

os.makedirs(norm_folder_path, exist_ok=True)
video_exts = ('.mp4', '.avi', '.mov', '.mkv') # 처리할 영상 확장자

# %%
from ultralytics import YOLO
import cv2
import pandas as pd
import numpy as np  # 정규화 계산을 위해 numpy 추가
import os
import glob # 파일 목록 비교를 위해 glob 추가
import time
from google.colab import drive

# 1. 드라이브 마운트 (최초 1회 실행)
try:
    drive.mount('/content/drive')
except:
    pass # 이미 마운트됨

# --- 2. 정규화 & 보간 함수 (Normalize & Interpolate) ---
# [최신 버전] 보간법이 포함된 정규화 함수입니다.
def normalize_keypoints_named(df):
    """
    [업그레이드 버전]
    1. 몸통 길이 기준으로 정규화 (Normalize)
    2. conf 낮은 값을 보간 (Interpolate)
    """
    df_norm = df.copy()

    # --- 1. 정규화 (Normalize) ---
    l_sh_x, l_sh_y = 'Left_Shoulder_x', 'Left_Shoulder_y'
    r_sh_x, r_sh_y = 'Right_Shoulder_x', 'Right_Shoulder_y'
    l_hip_x, l_hip_y = 'Left_Hip_x', 'Left_Hip_y'
    r_hip_x, r_hip_y = 'Right_Hip_x', 'Right_Hip_y'

    if l_sh_x not in df.columns or l_hip_x not in df.columns:
        print("   ⚠️ 정규화 필수 컬럼(어깨, 골반)이 없어 원본을 저장합니다.")
        return df

    neck_x = (df[l_sh_x] + df[r_sh_x]) / 2
    neck_y = (df[l_sh_y] + df[r_sh_y]) / 2
    pelvis_x = (df[l_hip_x] + df[r_hip_x]) / 2
    pelvis_y = (df[l_hip_y] + df[r_hip_y]) / 2

    torso_length = np.sqrt((neck_x - pelvis_x)**2 + (neck_y - pelvis_y)**2)
    torso_length = torso_length.replace(0, np.nan).fillna(1)

    body_parts = [
        'Nose', 'Left_Eye', 'Right_Eye', 'Left_Ear', 'Right_Ear',
        'Left_Shoulder', 'Right_Shoulder',
        'Left_Elbow', 'Right_Elbow', 'Left_Wrist', 'Right_Wrist',
        'Left_Hip', 'Right_Hip', 'Left_Knee', 'Right_Knee',
        'Left_Ankle', 'Right_Ankle'
    ]

    for part in body_parts:
        col_x = f'{part}_x'
        col_y = f'{part}_y'

        if col_x in df.columns and col_y in df.columns:
            df_norm[f'norm_{part}_x'] = (df[col_x] - pelvis_x) / torso_length
            df_norm[f'norm_{part}_y'] = (df[col_y] - pelvis_y) / torso_length

    # --- 2. 보간 (Interpolate) ---
    for part in body_parts:
        conf_col = f'{part}_conf'
        norm_x_col = f'norm_{part}_x'
        norm_y_col = f'norm_{part}_y'

        if conf_col in df_norm.columns and norm_x_col in df_norm.columns:
            low_conf_mask = df_norm[conf_col] < 0.5 # 0.5 미만 기준
            df_norm.loc[low_conf_mask, norm_x_col] = np.nan
            df_norm.loc[low_conf_mask, norm_y_col] = np.nan

    norm_cols = [col for col in df_norm.columns if col.startswith('norm_')]
    df_norm[norm_cols] = df_norm[norm_cols].interpolate(method='linear', limit_direction='both', limit=5)

    return df_norm

# --- 3. 메인 실행부 (YOLO + 정규화) ---

# --- [핵심 수정] 처리할 파일 목록 비교 ---
print("파일 목록 비교 중...")
all_videos = glob.glob(os.path.join(video_folder_path, "*")) # 모든 파일/폴더
all_video_files = [f for f in all_videos if f.lower().endswith(video_exts)] # 영상 파일만

# 2. 이미 'norm' 폴더에 있는 CSV 파일 목록 (이름만)
existing_norms = glob.glob(os.path.join(norm_folder_path, "norm_*.csv"))
# (예: 'norm_video1.csv' -> 'video1')
existing_norm_names = {os.path.basename(f).replace('norm_', '').replace('.csv', '') for f in existing_norms}

# 3. (비교) 처리해야 할 영상 목록 생성
videos_to_process = []
for video_path in all_video_files:
    # (예: '.../videos/video1.mp4' -> 'video1')
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    if video_name not in existing_norm_names:
        videos_to_process.append(video_path)

if not videos_to_process:
    print("🎉 모든 영상이 이미 정규화되었습니다. 새로 처리할 파일이 없습니다.")
    exit() # 프로그램 종료
else:
    print(f"총 {len(all_video_files)}개 영상 중 {len(videos_to_process)}개를 새로 처리합니다...")
# --- [비교 끝] ---

# 모델 로드
print("⏳ YOLO 모델을 로드 중입니다...")
model = YOLO('yolo11x-pose.pt') # (모델 경로 확인)
print("✅ 모델 로드 완료!")

# 컬럼 이름 미리 정의 (COCO Keypoints 17개)
keypoint_names = [
    "Nose", "Left_Eye", "Right_Eye", "Left_Ear", "Right_Ear",
    "Left_Shoulder", "Right_Shoulder", "Left_Elbow", "Right_Elbow",
    "Left_Wrist", "Right_Wrist", "Left_Hip", "Right_Hip",
    "Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"
]

# [수정] videos_to_process 목록만 순회
total_files = len(videos_to_process)
for i, video_path in enumerate(videos_to_process):
    filename = os.path.basename(video_path)
    csv_filename = os.path.splitext(filename)[0] + '.csv'
    save_path = os.path.join(norm_folder_path, f"norm_{csv_filename}")

    print(f"\n[{i+1}/{total_files}] 분석 중... {filename}")
    start_time = time.time()

    cap = cv2.VideoCapture(video_path)

    # (영상 안 볼거면 show_video = False로 변경)
    show_video = False
    if show_video:
        # ... (이전과 동일한 cv2.namedWindow 코드) ...
        pass

    video_data = [] # 영상 1개의 모든 프레임 데이터를 담을 리스트
    frame_idx = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret: break

        results = model(frame, verbose=False, conf=0.3) # (신뢰도 0.3으로 낮춰서 더 많이 잡게 설정)

        if results[0].keypoints is not None and len(results[0].keypoints) > 0:
            person_kpts = results[0].keypoints.data[0].cpu().numpy()
            frame_data = {"Frame": frame_idx}

            for k, kp in enumerate(person_kpts):
                x, y, conf = kp
                name = keypoint_names[k]
                frame_data[f"{name}_x"] = round(float(x), 2)
                frame_data[f"{name}_y"] = round(float(y), 2)
                frame_data[f"{name}_conf"] = round(float(conf), 2)

            video_data.append(frame_data)

        # ... (show_video 관련 코드) ...

        frame_idx += 1
        if frame_idx % 100 == 0: print(".", end="", flush=True)

    cap.release()
    if show_video: cv2.destroyAllWindows()

    # --- [핵심 수정] 저장 직전에 정규화+보간 적용 ---
    if video_data:
        df_raw = pd.DataFrame(video_data)

        print(" ...정규화 및 보간 적용 중...")
        # [업그레이드된 함수 호출]
        df_normalized_interpolated = normalize_keypoints_named(df_raw)

        df_normalized_interpolated.to_csv(save_path, index=False)

        elapsed = time.time() - start_time
        print(f"\n   ✅ 정규화 완료 및 저장! ({elapsed:.1f}초) -> {save_path}")
    else:
        print(f"\n   ⚠️ 데이터 없음 -> {filename}")

print("\n🎉 모든 신규 작업 끝!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 파일 목록 비교 중...
# 총 74개 영상 중 73개를 새로 처리합니다...
# ⏳ YOLO 모델을 로드 중입니다...
# ✅ 모델 로드 완료!
#
# [1/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.15.35_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (40.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.15.35_CAM_1.csv
#
# [2/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.17.02_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (42.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.17.02_CAM_1.csv
#
# [3/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP076_20220929_15.26.04_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (42.7초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP076_20220929_15.26.04_CAM_1.csv
#
# [4/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.10.42_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (36.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.10.42_CAM_1.csv
#
# [5/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.11.30_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (39.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.11.30_CAM_1.csv
#
# [6/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.12.19_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (38.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.12.19_CAM_1.csv
#
# [7/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.01.17_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (46.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.01.17_CAM_1.csv
#
# [8/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.02.15_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (43.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.02.15_CAM_1.csv
#
# [9/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.03.10_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (44.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.03.10_CAM_1.csv
#
# [10/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.50.10_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (44.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.50.10_CAM_1.csv
#
# [11/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.01_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (46.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.01_CAM_1.csv
#
# [12/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.54_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (48.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.54_CAM_1.csv
#
# [13/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.52.49_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (44.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.52.49_CAM_1.csv
#
# [14/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.53.42_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (46.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.53.42_CAM_1.csv
#
# [15/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.35.27_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (39.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.35.27_CAM_1.csv
#
# [16/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.36.16_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (39.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.36.16_CAM_1.csv
#
# [17/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.05_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (37.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.05_CAM_1.csv
#
# [18/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.52_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (42.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.52_CAM_1.csv
#
# [19/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.38.46_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (43.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.38.46_CAM_1.csv
#
# [20/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.39.39_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (42.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.39.39_CAM_1.csv
#
# [21/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP092_20221005_11.17.31_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (40.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP092_20221005_11.17.31_CAM_1.csv
#
# [22/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.07_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (39.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.07_CAM_1.csv
#
# [23/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.53_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (41.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.53_CAM_1.csv
#
# [24/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.37.42_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (39.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.37.42_CAM_1.csv
#
# [25/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.38.28_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (40.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.38.28_CAM_1.csv
#
# [26/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.39.18_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (43.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.39.18_CAM_1.csv
#
# [27/73] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40.12_CAM_1.mp4
# ..... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (41.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/norm/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40